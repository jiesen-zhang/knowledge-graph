# %% [markdown]
# # Introduction
#
# We will be using the text bodies in https://en.wikipedia.org/wiki/Border_Gateway_Protocol and http://caesar.cs.illinois.edu/papers/policies.pdf to create a singular knowledge graph regarding Border Gateway Policies (BGPs). In order to accomplish this, the work will be split into three major components: data preparation, information extraction and graph creation.

# %%
# !pip install ipynb
# !pip install 'decorator == 5.0.7'
import re
import pandas as pd
from ipynb.fs.full.my_functions import split_into_sentences

import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib
from matplotlib import pyplot as plt
# import tqdm
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %% [markdown]
# # Data Preparation
#
# Of the two documents, one is a PDF and the other a website. We want the data to be clean and readily usable, which means that we will have to convert both documents into a normalized, delimited text file. Preferably a CSV file.

# %% [markdown]
# We use the `tika` library to parse data from PDFs and convert them into a dictionary that contains the PDF's metadata, content and status. The content is the string equivalent of the PDF's text. There's still some junk data contained in the content, so I performed a bit of manual cleaning.

# %%
# !pip install tika
TIKA_SERVER_JAR="file:////tika-server.jar"

from tika import parser
raw = parser.from_file('documents/policies_clean.pdf')
contentPolicies = raw['content']

raw = parser.from_file('documents/BGP_clean.pdf')
contentBGP = raw['content']

# text_file = open("content.txt", "w")
# text_file.write(content)
# text_file.close()

# print(content)

# %% [markdown]
# ## Sentence Segmentation

# %% [markdown]
# `split_into_sentences()` is a reliable method to split text into sentences by using complex, handwritten regex methods. While effective, it is complicated and would be hard to update for those not proficient with regex. [Source.](https://stackoverflow.com/questions/4576077/how-can-i-split-a-text-into-sentences)

# %%
clean = split_into_sentences(contentPolicies)
# print(clean)

# %% [markdown]
# An amazing sentence segmenting algorithm is NLTK's Punkt Sentence Tokenizer. From `nltk.tokenize` documentation,
#
# >This tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences. It must be trained on a large collection of plaintext in the target language before it can be used.<br><br>The NLTK data package includes a pre-trained Punkt tokenizer for English. Source.
#
# [Source](https://www.nltk.org/api/nltk.tokenize.html)

# %%
import nltk.data
text = '''
Punkt knows that the periods in Mr. Smith and Johann S. Bach do not mark sentence boundaries.
And sometimes sentences can start with non-capitalized words.  
i is a good variable name.
'''
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
print('\n-----\n'.join(sent_detector.tokenize(text.strip())))
# Out:
# Punkt knows that the periods in Mr. Smith and Johann S. Bach do not mark sentence boundaries.
# -----
# And sometimes sentences can start with non-capitalized words.
# -----
# i is a good variable name.

# %% [markdown]
# It works great on many cases!

# %%
text2 = '''
During this time, it became apparent that vanilla shortest-path routing would be insufficient to handle the myriad operational, economic, and political factors involved in routing. 
ISPs began to modify routing configurations to support routing policies, i.e. goals held by the router’s owner that controlled which routes were chosen and which routes were propagated to neighbors.
'''
print('\n-----\n'.join(sent_detector.tokenize(text.strip())))
# Out:
# Punkt knows that the periods in Mr. Smith and Johann S. Bach do not mark sentence boundaries.
# -----
# And sometimes sentences can start with non-capitalized words.
# -----
# i is a good variable name.

# %% [markdown]
# But we still need to train it to catch abbreviations.

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters
punkt_param = PunktParameters()
abbreviation = ['i.e', 'e.g']
punkt_param.abbrev_types = set(abbreviation)

tokenizer = PunktSentenceTokenizer(punkt_param)
tokenizer.train(text2)

# %%
tokenizer.tokenize(text2)
# Out:
# ['\nDuring this time, it became apparent that vanilla shortest-path routing would be insufficient to handle the myriad operational, economic, and political factors involved in routing.',
#  'ISPs began to modify routing configurations to support routing policies, i.e. goals held by the router’s owner that controlled which routes were chosen and which routes were propagated to neighbors.']

# %% [markdown]
# Great, now our tokenizer can handle more cases!
#
# However we still face issues when we run into ordered lists. I am hesitant to train the model to detect numbers as abbreviations because there may be cases where sentences actually end with a number.

# %%
text3 = '''
There are three classes of “knobs” that can be used to control import and export policies: 
1. Preference influences which BGP route will be chosen for each destination prefix. 
Changing preference is done by adding/deleting/modifying route attributes in BGP advertisements. 
Table 1 shows which attributes can be modified during import to control preference locally, and which can be modified during export to change how much a neighbor prefers the route.
'''
print('\n-----\n'.join(sent_detector.tokenize(text3.strip())))
# Out:
# There are three classes of “knobs” that can be used to control import and export policies:
# 1.
# -----
# Preference influences which BGP route will be chosen for each destination prefix.
# -----
# Changing preference is done by adding/deleting/modifying route attributes in BGP advertisements.
# -----
# Table 1 shows which attributes can be modified during import to control preference locally, and which can be modified during export to change how much a neighbor prefers the route.

# %%
clean = tokenizer.tokenize(contentPolicies) + tokenizer.tokenize(contentBGP)
for i in range(len(clean)):
    clean[i] = clean[i].replace('\n','')
    clean[i] = clean[i].replace('\t','')

# %%
d = {'sentences': clean}
df = pd.DataFrame(d) 
    
# saving the dataframe as csv 
df.to_csv('policies_BGP.csv')

# %%
candidate_sentences = pd.read_csv('policies_BGP.csv')
del candidate_sentences['Unnamed: 0']
candidate_sentences.columns
# Out:
# Index(['sentences'], dtype='object')

# %%
candidate_sentences['sentences'].sample(2)
# Out:
# 238                     Three key areas of research related to BGP policy are discussed below (a wider survey of research directions is given in [18]).
# 21     Therefore, in order to understand BGP it is necessary to understand this decision process and the policies of ISPs that gave rise to its design.
# Name: sentences, dtype: object

# %% [markdown]
# # Entity Extraction/Named Entity Recognition
#
# <span style="color:red">to do: </span>
#     <ul>
#     <span style="color:red">
#         <li>research Chunking</li>
#         <li>optimize entity/relation extraction</li>
#     </span>
#     </ul>

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["sentences"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 521/521 [00:04<00:00, 127.40it/s]

# %%
entity_pairs
# Out:
# [['', ''],
#  ['Internet', 'administrative  entities'],
#  ['shortest path routing', 'operational  routing'],
#  ['routes', 'neighbors'],
#  ['BGP', 'substantially path vector complexity'],
#  ['they', 'which'],
#  ['common  policies', 'BGP'],
#  ['that', 'routing policies'],
#  ['', ''],
#  ['much  it', 'final  destination'],
#  ['shortest path routing', 'administrative  entity'],
#  ['vested  traffic', 'economic  reasons'],
#  ['forward route who', 'routes'],
#  ['first  it', ''],
#  ['ISPs', 'BGP'],
#  ['huge  that', 'unpredictable  ways'],
#  ['modifications', 'highly protocol specification'],
#  ['Moreover  complexity', 'different security ISPs'],
#  ['certain   they', 'new  design'],
#  ['decision BGP', 'routes'],
#  ['decision rest', 'fairly  time'],
#  ['decision that', 'design'],
#  ['also measurement what', 'new  BGP'],
#  ['hence  it', 'them'],
#  ['common network that', 'policies'],
#  ['how design they', 'ISP  mechanisms'],
#  ['6 control that', 'malicious  attacks'],
#  ['We', 'currently BGP policies'],
#  ['We', 'next  section'],
#  ['2  BGP', 'single  AS'],
#  ['Autonomous that', 'single  institution'],
#  ['BGP', 'reachability ASes'],
#  ['one  ISPs', 'two United ISPs'],
#  ['additional routing that', 'BGP protocol'],
#  ['border     border enterprises', 'border     border routers'],
#  ['core focus', 'ISP networks'],
#  ['then decision process', 'finally  policy'],
#  ['', 'routing  state'],
#  ['Figure', 'simple BGP network'],
#  ['border that', 'AS neighboring ASes'],
#  ['sessions', 'neighboring ASes'],
#  ['Border routers', 'internal border BGP'],
#  ['routers', 'one network another'],
#  ['forwarding that', 'chosen border router'],
#  ['BGP', 'few salient features'],
#  ['only  changes', 'information'],
#  ['changes', 'new route attributes'],
#  ['where path vector advertisements', 'destination'],
#  ['so prefix AS', 'reachable  prefixes'],
#  ['route that', 'advertised  route'],
#  ['modifying route routers', 'certain route attributes'],
#  ['2.2  Selecting', 'router'],
#  ['BGP router', 'particular  destination'],
#  ['router', 'same  pathlength'],
#  ['router', 'attributes'],
#  ['ordered BGP decision routes', 'Table'],
#  ['router', 'two  routes'],
#  ['otherwise  it', 'next  list'],
#  ['that', 'forward  packets'],
#  ['operator', 'various decision process'],
#  ['Local Preference', 'first decision process'],
#  ['longer  path', 'shorter  one'],
#  ['peering  link', 'attribute'],
#  ['ISP', 'LocalPref'],
#  ['strict policy it', 'configuration changes'],
#  ['certain decision they', 'different  order'],
#  ['various AS path which', 'unforeseen side effects'],
#  ['Locally  LocalPref', 'local neighboring ISPs'],
#  ['peering  link', 'next hop ASes'],
#  ['route', 'internal  protocol'],
#  ['four decision that', 'BGP attributes'],
#  ['then  that', 'IGP border router'],
#  ['other IGP routers', 'R2'],
#  ['three  router', 'route advertisements'],
#  ['routes', 'hence  attributes'],
#  ['Next  router', 'desirable decision route'],
#  ['neighbors', 'chosen  route'],
#  ['certain export neighbors', 'export routes'],
#  ['how  neighbors', 'route selection'],
#  ['', ''],
#  ['three  that', 'import  policies'],
#  ['BGP route', 'destination prefix'],
#  ['Changing  preference', 'deleting BGP advertisements'],
#  ['much  neighbor', 'route'],
#  ['', ''],
#  ['also  they', 'also  who'],
#  ['Filtering', 'inbound  preference'],
#  ['Filtering', 'specified  values'],
#  ['', ''],
#  ['additional  which', 'AS boundaries'],
#  ['key  mechanism', 'variable tag routes'],
#  ['complex  that', 'other  means'],
#  ['route', 'router'],
#  ['community', 'usage'],
#  ['ISP', 'configuration routers'],
#  ['one tagging router', 'speaking  router'],
#  ['routes', 'peers'],
#  ['advertisement', 'specified  route'],
#  ['', ''],
#  ['next hop they', 'neighbors'],
#  ['primary  routes', 'failure'],
#  ['when  both', 'learned  peers'],
#  ['This', 'other ISP party'],
#  ['90  99', 'backup  links'],
#  ['LocalPref', 'then business Section'],
#  ['large  ISP', 'expensive transatlantic link'],
#  ['This', 'lower  routes'],
#  ['forward  it', 'one  another'],
#  ['This', 'when community peers'],
#  ['It', 'this'],
#  ['which', 'ordinarily route AS'],
#  ['', 'internal iBGP network'],
#  ['export that', 'Xpeer'],
#  ['', ''],
#  ['available  that', 'relative  routes'],
#  ['Moreover  ISPs', 'available  routes'],
#  ['secondary  goal', 'desired performance quality'],
#  ['import each', 'different  configuration'],
#  ['selected traffic engineering routes', '4'],
#  ['routes', 'good IGP link costs'],
#  ['where hotpotato ISP', 'internal links network'],
#  ['early network BGP', 'multiple  ISPs'],
#  ['common  goal', 'outbound  neighbors'],
#  ['This', 'several  links'],
#  ['Outbound traffic engineering', 'LocalPref'],
#  ['it', 'maintenance'],
#  ['C.  Achieving', 'spare load links'],
#  ['large  set', 'much  links'],
#  ['It', 'long router configuration file'],
#  ['many  prefixes', 'it'],
#  ['changing  outcome', 'change'],
#  ['automated  ISP', 'actions'],
#  ['neighbors', 'internal privacy reasons'],
#  ['much  it', 'peering  links'],
#  ['remote route which', 'ISP  goals'],
#  ['much  it', 'neighbor'],
#  ['MED which', 'peering  links'],
#  ['MED attribute link', 'thereby  load'],
#  ['unfortunately  BGP', 'multiple route hops'],
#  ['commonly  AS', 'artificially AS path length'],
#  ['AS path which', 'more  comparison'],
#  ['certain community ISP', 'desired  policy'],
#  ['C peers', 'figure'],
#  ['human  B', 'often traffic engineering purposes'],
#  ['B', 'certain LocalPref 2'],
#  ['C', 'certain  own'],
#  ['C', 'higher  85'],
#  ['Remote  control', 'inbound  traffic'],
#  ['typically  customer', 'behalf'],
#  ['more  it', 'earlier decision example'],
#  ['remote  control', 'AS prepending'],
#  ['next hop LocalPref', 'neighbors'],
#  ['However  neighbors', 'other community peer'],
#  ['expressive  nature', 'community misconfiguration'],
#  ['route', 'it'],
#  ['unintended  consequences', 'them'],
#  ['careful router they', 'customers'],
#  ['', 'upstream  providers'],
#  ['unstable  routes', 'unstable  routes'],
#  ['Moreover  tools', 'outgoing traffic 5'],
#  ['', ''],
#  ['misconfigurations', 'excessive  updates'],
#  ['poor memory which', 'outages'],
#  ['configured  set', 'BGP problems'],
#  ['router', '7'],
#  ['smaller  which', 'less memory capacity'],
#  ['', ''],
#  ['other  ISPs', 'longer  aggregation'],
#  ['neighbor', 'prefixes'],
#  ['most default destinations', 'instead default which'],
#  ['', ''],
#  ['adjacent route they', 'specific export 9'],
#  ['effectively  which', 'following BGP example'],
#  ['E', '2 prefix 6.0.0.0/8'],
#  ['new customer which', 'subnet 6.1.1.0/24'],
#  ['new  advertisements', 'impacts'],
#  ['', ''],
#  ['already AS R5', 'specific  6.1.1.0/24'],
#  ['new  advertisements', 'internally  E.'],
#  ['', ''],
#  ['they', 'R5'],
#  ['hence address E', 'BGP neighbors'],
#  ['community', 'community attribute'],
#  ['', ''],
#  ['longest prefix routers', 'F ’s route'],
#  ['E', 'prefix'],
#  ['E', 'certain community attribute'],
#  ['CPU which', 'important reaction events'],
#  ['frequent  shifting', 'round trip time calculations'],
#  ['key  mechanism', 'stability'],
#  ['that', 'unstable  routes'],
#  ['whenever  update', 'penalty route'],
#  ['i.e.  it', 'decision process'],
#  ['ISP', 'route availability'],
#  ['ISPs', 'high availability requirements'],
#  ['shorter  damping', 'large  reachability'],
#  ['route that', 'specific prefix parameters'],
#  ['', ''],
#  ['AS', 'false  BGP'],
#  ['routing routers', 'service quality'],
#  ['several  AS', 'information'],
#  ['Such  information', 'sometimes router bugs'],
#  ['vested  customers', 'service'],
#  ['Hence  ISP', 'defensive  attacks'],
#  ['invalid import ISPs', 'invalid update them'],
#  ['use  that', 'use  blocks'],
#  ['they', 'prefixes'],
#  ['that', 'AS path'],
#  ['Also  advertisements', 'private AS path'],
#  ['ISPs', 'private routing neighbors'],
#  ['routing ISP', 'peering routing agreement'],
#  ['Otherwise  ISP', 'longer  behalf'],
#  ['', 'New York'],
#  ['Francisco peering San Francisco point', 'York peering point'],
#  ['peer', 'wrongly New York router'],
#  ['peering  ISP', 'expected import values'],
#  ['MED ISP', 'MEDs'],
#  ['Similarly import policy', 'unexpected community values'],
#  ['Unfortunately  techniques', 'peering  agreements1'],
#  ['that', 'destinations'],
#  ['ISP', 'own router interfaces'],
#  ['ISP', 'internal network management software'],
#  ['Finally  ISP', 'preventative export measure'],
#  ['Denial  attacks', 'excessive  link'],
#  ['neighbor', 'large destination prefixes'],
#  ['import policy', 'longer mask /24'],
#  ['neighbor', 'easily CPU routers'],
#  ['operators', 'offending BGP session'],
#  ['completely filter it', 'sources'],
#  ['excessive data traffic', 'victim hosts'],
#  ['traffic', 'victim addresses'],
#  ['special BGP that', 'victims'],
#  ['monitoring that', 'further  traffic'],
#  ['similar  ISP', 'known address addresses'],
#  ['i.e. TCP which', 'mail servers'],
#  ['7', ''],
#  ['protocol  it', 'highly  misconfiguration'],
#  ['challenge', 'much research activity'],
#  ['wider BGP survey', 'research 18'],
#  ['policies', 'configuration mistakes'],
#  ['Interdependence', 'persistent route oscillations'],
#  ['modeling consistency criteria tools', 'configuration ISP'],
#  ['uncoordinated routing policy', 'route convergence'],
#  ['Routing Arbiter Routing project', 'distributed routing problems'],
#  ['Other  work', 'private route policy policies'],
#  ['Language design', 'ISP Policy Specification policy'],
#  ['It', 'together  consistency'],
#  ['RPSL', ''],
#  ['however design design', 'language'],
#  ['', 'several routing BGP'],
#  ['HLP', 'proposed  eBGP'],
#  ['common  that', 'resulting interdomain routes'],
#  ['centralized  that', 'ISP'],
#  ['AS RCP', 'best destination router'],
#  ['This', 'misconfiguration'],
#  ['', ''],
#  ['common design that', 'typically  ISPs'],
#  ['how  they', 'BGP policy mechanisms'],
#  ['that', 'common  cases'],
#  ['Border Gateway Protocol', 'autonomous gateway Internet'],
#  ['vector routing it', 'network administrator'],
#  ['BGP', 'autonomous  system'],
#  ['Internet application', 'protocol'],
#  ['Border Gateway Protocol', '1105  1994'],
#  ['1883  it', '2283  1998'],
#  ['4  which', '4271  2006'],
#  ['', 'common industry practices'],
#  ['major  enhancement', 'routing tables'],
#  ['BGP4', 'wide  IPv4'],
#  ['also Multiprotocol which', ''],
#  ['BGP neighbors', 'manual TCP port'],
#  ['BGP speaker', '60  connection'],
#  ['BGP', 'transport protocol'],
#  ['autonomous  it', 'Internal BGP'],
#  ['autonomous  it', 'autonomous  systems'],
#  ['directly i BGP peers', 'intermediate  routers'],
#  ['remote VPN sites', 'secure  manner'],
#  ['way that', 'other  peers'],
#  ['other transit mode', 'router'],
#  ['then iBGP they', 'only eBGP peers'],
#  ['effectively iBGP peers', 'full  mesh'],
#  ['propagated', 'route maps mechanism'],
#  ['mechanism', 'rules'],
#  ['given  action', 'given  criteria'],
#  ['it', 'routing table'],
#  ['BGP speakers', 'multiprotocol  extensions[8'],
#  ['Layer Reachability it', 'address family prefix'],
#  ['families', 'IPv4  default'],
#  ['signaling  that', 'such  VPNs'],
#  ['finite state that', 'six  states'],
#  ['six  session', 'six  states'],
#  ['peer', 'one  another'],
#  ['first  state', ''],
#  ['Idle BGP', 'TCP peer'],
#  ['second  state', ''],
#  ['TCP connection', 'OpenSent state'],
#  ['it', 'Active ConnectRetry expiration'],
#  ['Active  router', 'Connect state'],
#  ['OpenSent router', 'Open OpenConfirm state'],
#  ['successful  router', 'Established  state'],
#  ['Established  router', 'Notification peer'],
#  ['full  router', 'other  router'],
#  ['number', 'quadratically  routers'],
#  ['BGP', 'two  options'],
#  ['following  discussion', 'full iBGP mesh'],
#  ['given BGP router', 'different Layer Reachability neighbors'],
#  ['Conceptually  BGP', 'main routing router'],
#  ['outgoing RIB NLRI', 'neighbor'],
#  ['physical  storage', 'conceptual BGP code'],
#  ['other BGP they', 'local management router'],
#  ['It', 'additional RIB entries'],
#  ['eligible Loc RIB entries', 'local table management process'],
#  ['it', 'main routing table process'],
#  ['BGP route', 'process'],
#  ['connected  prefix', 'own  hardware'],
#  ['BGP route', 'routing table'],
#  ['preferred Loc RIB route', 'main routing table'],
#  ['common  BGP', 'policies'],
#  ['BGP', 'speaking policy decisions'],
#  ['that', 'explicitly policy decisions'],
#  ['more decision that', 'common Loc RIB'],
#  ['next hop attribute', 'NLRI'],
#  ['next hop address', 'main routing which'],
#  ['implementation  routes', 'conceptually Adj RIB In'],
#  ['first  level', 'neighbor level'],
#  ['one  route', 'conceptual Adj RIB In'],
#  ['also Adj RIB that', 'neighbor'],
#  ['any', 'already Loc RIB'],
#  ['it', 'them'],
#  ['other  route', 'main routing table manager'],
#  ['withdrawn BGP route', 'main routing table'],
#  ['route', 'rule  attribute'],
#  ['several iBGP LOCAL_PREFERENCE', 'several  LOCAL_PREFERENCE'],
#  ['latter route selection process', 'next  tiebreaker'],
#  ['first decision which', 'i.e.  BGP'],
#  ['route', 'highest  WEIGHT'],
#  ['LOCAL_PREFERENCE', 'configuration  capabilities'],
#  ['Such  manipulation', 'commonly  standard'],
#  ['COMMUNITY attribute', 'directly BGP selection process'],
#  ['programmed COMMUNITY value', 'pattern  criterion'],
#  ['per BGP process', 'then policy neighbor'],
#  ['specific policy order', 'breaking  rules'],
#  ['', 'shortest  AS_PATH'],
#  ['AS that', 'advertised  destination'],
#  ['AS1 AS2 AS3', 'AS4 AS5 AS6- AS7'],
#  ['', ''],
#  ['', 'lowest ORIGIN attribute'],
#  ['', ''],
#  ['', 'exit  value'],
#  ['Loc RIB software', 'same tie destination'],
#  ['', ''],
#  ['i.e.  route', 'iBGP'],
#  ['', ''],
#  ['', 'main routing table'],
#  ['other bitrate routes', 'high bitrate link'],
#  ['several BGP implementations', 'configurable load number'],
#  ['', ''],
#  ['', 'identifier BGP'],
#  ['that', 'common  goal'],
#  ['this', 'ISPs'],
#  ['one  AS', 'peering  customers'],
#  ['how  prefixes', 'known  one'],
#  ['known  that', 'global  significance'],
#  ['RFC', '7611  ACCEPT_OWN'],
#  ['Examples', 'black prepending options'],
#  ['community XXX:501', 'North America'],
#  ['prefix', 'who'],
#  ['correct  problems', 'area'],
#  ['instead ISP effect', 'instead ISP MED'],
#  ['communities', 'next hop AS'],
#  ['others', 'public'],
#  ['Extended Community Attribute', 'such type field'],
#  ['extended  format', 'respective community attribute content'],
#  ['definition', 'Extended Community RFC'],
#  ['IANA', 'Extended Communities Types'],
#  ['Extended Communities Attribute', ''],
#  ['extended type community', 'transitive  nature'],
#  ['IANA registry', 'different attribute types'],
#  ['extended attribute usage', 'extended attribute range'],
#  ['RFC', 'exemplarily Specific Extended Community'],
#  ['number', 'domain QoS signalling'],
#  ['extended  communities', '32 bit ASNs'],
#  ['16 bits ASN which', 'field'],
#  ['why  RFC', '4 Large parameter'],
#  ['MEDs', 'inbound BGP traffic'],
#  ['they', 'destination'],
#  ['BGP', 'routing  protocols'],
#  ['where iBGP everyone', 'everyone'],
#  ['router', 'other  router'],
#  ['large  number', 'memory'],
#  ['Route', 'AS'],
#  ['other route routers', 'only  them'],
#  ['route reflector', 'internal border gateway protocol'],
#  ['RR', 'IBGP sessions'],
#  ['purpose', 'RR'],
#  ['central  RR', 'full route reflector mesh'],
#  ['other IBGP routers', ''],
#  ['approach', 'added IBGP scalability'],
#  ['remote  this', 'remote  peer'],
#  ['RR topology', 'larger  ISPs'],
#  ['second route reflector', 'redundancy'],
#  ['10  it', 'single Route Reflector setup'],
#  ['', 'additional 2 Router'],
#  ['local Routing RRs', 'dedicated Reflector Server role'],
#  ['following  route', 'only  peers'],
#  ['route', 'also EBGP peers'],
#  ['RR', 'Cluster'],
#  ['Cluster ID', 'client  peers'],
#  ['transitive BGP RR', 'local routing loops'],
#  ['Route reflectors', 'thus processing overhead'],
#  ['enhancing  confederations', 'grained  policy'],
#  ['Confederations', 'autonomous  systems'],
#  ['only  numbers', 'whole'],
#  ['large  AS', 'internal  ASs'],
#  ['confederated  AS', 'multiple  ASs'],
#  ['alone  iBGP', 'other  confederation'],
#  ['they', 'iBGP'],
#  ['confederation', 'next preference information'],
#  ['outside  confederation', 'outside  world'],
#  ['iBGP', 'unnecessary TCP traffic'],
#  ['Confederations', 'route reflectors'],
#  ['specific design rules', 'BGP'],
#  ['However  alternatives', 'optimal BGP convergence time'],
#  ['Additionally route reflectors', 'BGP router configuration'],
#  ['Nevertheless  these', 'experienced BGP network architects'],
#  ['tools', 'route reflectors'],
#  ['routing tables', 'such BGP links'],
#  ['particular  changes', 'particular  router'],
#  ['then  it', 'down  states'],
#  ['same  route', 'continually routing tables'],
#  ['routes', 'traffic'],
#  ['BGP routing change', 'several  minutes'],
#  ['feature', 'many route flapping'],
#  ['heavy processing which', 'routing  stability'],
#  ['flapping', 'damping'],
#  ['quickly  damping', 'normal fail over BGP'],
#  ['subsequent  occurrences', 'certain  time'],
#  ['slate', 'offending  route'],
#  ['also service damping', 'timings'],
#  ['autonomous  it', 'particular  backbone'],
#  ['method', 'successfully iBGP sessions'],
#  ['when convergence links', 'actually convergence connectivity'],
#  ['as  it', 'faster routing routers'],
#  ['current Routing Working application', 'ISP networks'],
#  ['ISP', 'Internet content'],
#  ['side effects', 'simply  flap'],
#  ['Improving', 'current flap research'],
#  ['One', 'indeed Internet routing table'],
#  ['effective  they', 'effective  Internet'],
#  ['larger routing tables', 'even network interim'],
#  ['global routing table', 'widespread  connectivity'],
#  ['ISPs', 'possible - Domain Routing'],
#  ['this', 'again end 2004'],
#  ['like  that', 'like  models'],
#  ['older  routers', 'table entries'],
#  ['2014  outages', 'full Microsoft others'],
#  ['addressable Cisco BGP', 'routes'],
#  ['impacted  TCAM', 'default 512k IPv4 routes'],
#  ['spillover default routers', 'fast software TCAM'],
#  ['IPv6 TCAM which', 'most  routers'],
#  ['512k problem', 'IT professionals'],
#  ['which', '07:48  UTC'],
#  ['new routing table', '515,000  entries'],
#  ['5  instability', 'apparently  hours'],
#  ['short  it', 'natural  growth'],
#  ['Route summarization', 'necessary table AS'],
#  ['one traffic engineering AS1', '172.16.0.0  /18'],
#  ['AS1', 'specific  route'],
#  ['AS1', 'four  routes'],
#  ['four routing 172.16.0.0/16', 'just  summary'],
#  ['it', 'route'],
#  ['unreachable ICMP message', 'back  routers'],
#  ['it', 'three'],
#  ['three routing it', 'only routes AS2 172.16.0.0/17'],
#  ['back  172.16.192.0/18', 'routing table'],
#  ['private AS 0', 'private AS use'],
#  ['15000 AS numbers', 'available AS September'],
#  ['reserved AS which', 'available 4 AS'],
#  ['private AS range', '6996  RFC'],
#  ['new router attribute', 'new router ASNs'],
#  ['32 bit ASN assignments', '2007'],
#  ['factor', 'homed load networks'],
#  ['It', 'inbound route selection process'],
#  ['external  networks', 'congested  paths'],
#  ['other routing BGP', 'congestion'],
#  ['external  networks', 'different  network'],
#  ['Such  cases', 'global BGP table'],
#  ['One  method', 'multiple ingress traffic links'],
#  ['technique', 'global BGP table'],
#  ['routers', 'other BGP default'],
#  ['automatic  it', 'accidental BGP hijacking'],
#  ['different  which', 'cryptographic BGP routers'],
#  ['equal AS path path', 'actual AS path'],
#  ['further  which', 'individual traffic links'],
#  ['4760 IETF that', 'different address parallel'],
#  ['IPv6  it', 'unicast  each'],
#  ['Multiprotocol BGP', 'unicast  routers'],
#  ['multicast routing topology', 'unicast routing topology'],
#  ['other multicast routing protocols', 'such Independent Multicast trees'],
#  ['when customer traffic', 'other PE routing'],
#  ['BGP4', 'most Internet service one'],
#  ['private IP networks', 'BGP'],
#  ['when Shortest Path OSPF', 'size'],
#  ['reason', 'multiple access ISPs'],
#  ['Routers', 'Small Office BGP software'],
#  ['SOHO  routers', 'simply  size'],
#  ['that', 'it'],
#  ['that', 'GNU Zebra'],
#  ['3 end Switches', 'usually  BGP'],
#  ['Products', 'internal Internet routes'],
#  ['small BGP that', 'aggregated default routes'],
#  ['used', 'multihomed CPU network'],
#  ['simple  multihoming', 'modest routing table size'],
#  ['', 'single control plane'],
#  ['actual  amount', 'other BGP which'],
#  ['one  it', 'specific neighboring AS'],
#  ['term view', 'running policy router'],
#  ['more  this', 'legitimate trading processing memory'],
#  ['BGP table', '590,000  prefixes'],
#  ['Large  ISPs', 'internal  routes'],
#  ['separate  tables', 'different  peer']]

# %% [markdown]
# # Relation Extraction

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1",[pattern]) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['sentences'])]
# Out:
# 100%|██████████| 521/521 [00:03<00:00, 139.95it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# is               50
# are              18
# done by           9
# have              7
# wish              7
# allows            6
# be                6
# was               5
# 2                 5
# learned from      5
# used              4
# defines           4
# called            4
# need              4
# used for          4
# 3                 4
# used by           4
# do                3
# Prefer            3
# maintains         3
# applied           3
# has               3
# reduce            3
# were              3
# increase          3
# suppose           3
# cause             3
# use               3
# include           3
# consists of       3
# implements        3
# routes with       2
# generated by      2
# exchanged         2
# protect           2
# used in           2
# require           2
# is in             2
# installed in      2
# simplifies        2
# marketed as       2
# trigger           2
# decides           2
# request           2
# configured as     2
# modify            2
# shows             2
# gives             2
# want              2
# preferred         2
# dtype: int64

# %% [markdown]
# # Creating the Graph

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="is"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
